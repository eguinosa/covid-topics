# %%
import warnings
import pyLDAvis
from pyLDAvis import gensim_models
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.models import LdaModel

# Turn off warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# Loading the dictionary and corpus.
dictionary = Dictionary.load('data/dictionary.dict')
corpus_bow = corpora.MmCorpus('data/corpus_bow.mm')
lda_model = LdaModel.load('data/current_lda_model')

# Use PyLDAvis to vizualize the topics
visual_data = gensim_models.prepare(topic_model=lda_model, corpus=corpus_bow, dictionary=dictionary)
pyLDAvis.enable_notebook()
pyLDAvis.display(visual_data)
# Out:
# /Users/gelin/Projects/Python/covid_topics/venv/lib/python3.8/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1640643534308006428198097"></div>
# <script type="text/javascript">
#
# ...
